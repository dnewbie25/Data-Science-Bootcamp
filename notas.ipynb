# %%
from xml.dom.minidom import Entity
import pandas as pd
import numpy as np

# %%
datos_1 = pd.read_csv('datasets\Fuentes_Consumo_Energia.csv', delimiter=',', encoding='utf-8')
col_mex = datos_1[(datos_1.Entity=='Colombia')|(datos_1.Entity=='Mexico')]
tupla = (col_mex[col_mex.Entity=='Colombia'].shape[0],col_mex[col_mex.Entity=='Mexico'].shape[0])
tupla
# Out:
# (55, 55)

# %%
datos_2 = pd.read_csv('datasets\Fuentes_Consumo_Energia.csv', delimiter=',', encoding='utf-8')
datos_2.drop(columns=['Code','Entity'], inplace=True)
datos_2.shape
# Out:
# (5190, 9)

# %%
datos_3 = pd.read_csv('datasets\Fuentes_Consumo_Energia.csv', delimiter=',', encoding='utf-8')
datos_3.Year.count()
datos_3[datos_3.Entity=='World']
# Out:
#      Entity      Code  Year  Coal_Consumption_EJ  Gas_Consumption_EJ  \
# 5135  World  OWID_WRL  1965            58.104642           22.693676
# 5136  World  OWID_WRL  1966            58.766738           24.727660
# 5137  World  OWID_WRL  1967            57.818915           26.546542
# 5138  World  OWID_WRL  1968            58.684128           28.959593
# 5139  World  OWID_WRL  1969            60.475449           31.800305
# 5140  World  OWID_WRL  1970            61.410989           34.613250
# 5141  World  OWID_WRL  1971            61.077453           37.051894
# 5142  World  OWID_WRL  1972            61.755597           39.100893
# 5143  World  OWID_WRL  1973            63.604258           40.956192
# 5144  World  OWID_WRL  1974            63.655384           41.962491
# 5145  World  OWID_WRL  1975            64.888336           41.979868
# 5146  World  OWID_WRL  1976            67.278546           44.478225
# 5147  World  OWID_WRL  1977            69.268657           45.938261
# ...

# %%
datos_4 = pd.read_csv('datasets\Fuentes_Consumo_Energia.csv', delimiter=',', encoding='utf-8')
datos_4.head()
# Out:
#    Entity Code  Year  Coal_Consumption_EJ  Gas_Consumption_EJ  \
# 0  Africa  NaN  1965             1.164586            0.034358
# 1  Africa  NaN  1966             1.163240            0.038412
# 2  Africa  NaN  1967             1.189050            0.037964
# 3  Africa  NaN  1968             1.236646            0.038480
# 4  Africa  NaN  1969             1.247915            0.044971
#
#    Geo_Biomass_Other_TWh  Hydro_Generation_TWh  Nuclear_Generation_TWh  \
# 0                    0.0             13.905635                     0.0
# 1                    0.0             15.510004                     0.0
# 2                    0.0             16.190636                     0.0
# 3                    0.0             18.938341                     0.0
# 4                    0.0             22.100890                     0.0
#
#    Solar_Generation_TWh  Wind_Generation_TWh  Oil_Consumption_EJ
# 0                   0.0                  0.0            1.173241
# ...

# %%
datos_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5190 entries, 0 to 5189
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Entity                  5190 non-null   object
#  1   Code                    4145 non-null   object
#  2   Year                    5190 non-null   int64
#  3   Coal_Consumption_EJ     5170 non-null   float64
#  4   Gas_Consumption_EJ      5170 non-null   float64
#  5   Geo_Biomass_Other_TWh   5115 non-null   float64
#  6   Hydro_Generation_TWh    5170 non-null   float64
#  7   Nuclear_Generation_TWh  5170 non-null   float64
#  8   Solar_Generation_TWh    5170 non-null   float64
#  9   Wind_Generation_TWh     5170 non-null   float64
#  10  Oil_Consumption_EJ      5184 non-null   float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 446.1+ KB

# %%
def thw_to_exj(numero):
  return 277.778*numero
datos_4[['Coal_Consumption_EJ','Gas_Consumption_EJ','Oil_Consumption_EJ']]=datos_4[['Coal_Consumption_EJ','Gas_Consumption_EJ','Oil_Consumption_EJ']].apply(thw_to_exj)
datos_4['Consumo_Total'] = datos_4['Coal_Consumption_EJ']+datos_4['Gas_Consumption_EJ']+datos_4['Oil_Consumption_EJ']+datos_4['Geo_Biomass_Other_TWh'] + datos_4['Hydro_Generation_TWh'] + datos_4['Nuclear_Generation_TWh'] + datos_4['Solar_Generation_TWh'] + datos_4['Wind_Generation_TWh']

# %%
float(datos_4[(datos_4.Entity=='World')&(datos_4.Year==2019)].Consumo_Total.round(2))
# Out:
# 5189    146585.3
# Name: Consumo_Total, dtype: float64

# %%
datos_5 = pd.read_csv('datasets\Fuentes_Consumo_Energia.csv', delimiter=',', encoding='utf-8')
europa = datos_5[datos_5.Entity=='Europe']
europa.reset_index(inplace=True)
indice_max = europa.Hydro_Generation_TWh.idxmax()
europa.iloc[indice_max].Year
# Out:
# 2013

# %%
n1 = np.array([[0,0,0],[1,1,1],[2,2,2],[3,3,3],[4,4,4],[5,5,5]])
n2 = np.array([[6,7],[8,6],[7,8]])
n3 = np.array([[9,9],[10,10]])

def se_puede_hacer_broadcast(array1, array2):
    for a, b in zip(array1[::-1], array2[::-1]):
        if a.any() == 1 or b.any() == 1 or a.any() == b.any():
            pass
        else:
            return False
    return True

# %%
is_broadcastable(n1,n3)
# Out:
# True

# %%
n1.shape
# Out:
# (6, 3)

# %%
n2.shape
# Out:
# (3, 2)

# %%
n3.shape
# Out:
# (2, 2)

# %%
n3.shape > n2.shape
# Out:
# False

# %%
n1[::-1]
# Out:
# array([[5, 5, 5],
#        [4, 4, 4],
#        [3, 3, 3],
#        [2, 2, 2],
#        [1, 1, 1],
#        [0, 0, 0]])

# %%
datos_7 = pd.read_csv('datasets\GGAL - Cotizaciones historicas.csv', delimiter=',', encoding='utf-8')
datos_7.maximo.sum().round(4)
# Out:
# 202185.8933

# %%
datos_8 = pd.read_csv('datasets\Fuentes_Consumo_Energia.csv', delimiter=',', encoding='utf-8')
len(datos_8.Entity.unique())
# Out:
# 100

# %%
tabla1 = pd.read_csv('datasets\Tabla1_ejercicio.csv', delimiter=';', encoding='utf-8')
tabla2 = pd.read_csv('datasets\Tabla2_ejercicio.csv', delimiter=';', encoding='utf-8')

# %%
datos_9 = pd.merge(tabla1, tabla2, on='pers_id')
datos_9.head()
# Out:
#        pers_id sexo  edad      ingreso            situacion_lab  periodo  \
# 0  71906556521    F    47  35926.28125  Sin_situacion_declarada   201906
# 1  71906556521    F    47  35926.28125  Sin_situacion_declarada   201906
# 2  71906556521    F    47  35926.28125  Sin_situacion_declarada   201909
# 3  71906556521    F    47  35926.28125  Sin_situacion_declarada   201909
# 4  71906556521    F    47  35926.28125  Sin_situacion_declarada   201912
#
#    score
# 0    919
# 1    919
# 2    738
# 3    919
# 4    919

# %%
datos_9.drop_duplicates(inplace=True)
datos_9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14721 entries, 0 to 15875
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pers_id        14721 non-null  int64
#  1   sexo           14721 non-null  object
#  2   edad           14721 non-null  int64
#  3   ingreso        14721 non-null  float64
#  4   situacion_lab  14721 non-null  object
#  5   periodo        14721 non-null  int64
#  6   score          14721 non-null  int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 920.1+ KB

# %%
datos_9.drop_duplicates(inplace=True, subset=['periodo', 'score'])
datos_9.head()
# Out:
#         pers_id sexo  edad      ingreso            situacion_lab  periodo  \
# 0   71906556521    F    47  35926.28125  Sin_situacion_declarada   201906
# 2   71906556521    F    47  35926.28125  Sin_situacion_declarada   201909
# 3   71906556521    F    47  35926.28125  Sin_situacion_declarada   201909
# 4   71906556521    F    47  35926.28125  Sin_situacion_declarada   201912
# 12  73861260912    F    41  16231.12207  Sin_situacion_declarada   201906
#
#     score
# 0     919
# 2     738
# 3     919
# 4     919
# 12    557

# %%
score_prom_masculino = datos_9[(datos_9.sexo=='M')].score.mean()
score_prom_femenino = datos_9[(datos_9.sexo=='F')].score.mean()
(score_prom_masculino, score_prom_femenino)
# Out:
# (772.2811111111112, 630.261911750318)

# %%
import Lista as l
lis = l.Lista()
